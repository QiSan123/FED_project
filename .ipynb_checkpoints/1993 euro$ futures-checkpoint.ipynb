# %%
import eikon as eikon
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import datetime as dt
from matplotlib.ticker import FuncFormatter
from functools import partial

# %%
 eikon.set_app_key('1153655a813e49b09943821a11d273d879402478')

# %%
rics = ['EDc1', 'EDc2', 'EDc3', 'EDc4', 'EDc5', 'EDc6','EDc7', 'EDc8', 
        'EDc9','EDc10','EDc11','EDc12',
        'EDc13','EDc14', 'EDc15','EDc16']

# %%
table1 = eikon.get_timeseries (rics, fields ='CLOSE', start_date = '1993-01-01', end_date = '1993-04-06' , interval = 'daily', calendar='native')
table2 = eikon.get_timeseries (rics, fields ='CLOSE', start_date = '1993-04-07', end_date = '1993-12-31' , interval = 'daily', calendar='native')
table = pd.concat([table1, table2], ignore_index= False)
table
# Out:
# CLOSE        EDc1   EDc2   EDc3   EDc4   EDc5   EDc6   EDc7   EDc8   EDc9  \
# Date
# 1993-01-04  96.44  96.07  95.65  95.03  94.81  94.46  94.16  93.73  93.62
# 1993-01-05  96.42  96.05  95.63  95.01  94.79  94.44  94.14  93.72  93.62
# 1993-01-06  96.41  96.04  95.61  94.99  94.77  94.42  94.13  93.72  93.62
# 1993-01-07  96.38  95.94  95.48  94.86  94.64  94.30  94.01  93.60  93.50
# 1993-01-08  96.47  96.10  95.65  95.02  94.79  94.42  94.11  93.68  93.56
# 1993-01-11  96.48  96.13  95.71  95.09  94.86  94.49  94.18  93.75  93.63
# 1993-01-12  96.48  96.11  95.68  95.07  94.85  94.48  94.17  93.74  93.62
# 1993-01-13  96.49  96.14  95.73  95.12  94.89  94.52  94.21  93.78  93.66
# 1993-01-14  96.53  96.22  95.83  95.23  94.99  94.60  94.28  93.84  93.71
# 1993-01-15  96.64  96.34  95.97  95.38  95.11  94.70  94.36  93.91  93.78
# 1993-01-18  96.64  96.34  95.96  95.36  95.10  94.69  94.35  93.90  93.77
# 1993-01-19  96.60  96.31  95.91  95.32  95.07  94.67  94.34  93.89  93.76
# ...

# %%
#changing the price to rates
Dates = table.index.tolist()
EDc1 = (100-table['EDc1']).tolist()
EDc2 = (100-table['EDc2']).tolist()
EDc3 = (100-table['EDc3']).tolist()
EDc4 = (100-table['EDc4']).tolist()
EDc5 = (100-table['EDc5']).tolist()
EDc6 = (100-table['EDc6']).tolist()
EDc7 = (100-table['EDc7']).tolist()
EDc8 = (100-table['EDc8']).tolist()
EDc9 = (100-table['EDc9']).tolist()
EDc10 = (100-table['EDc10']).tolist()
EDc11 = (100- table['EDc11']).tolist()
EDc12 = (100-table['EDc12']).tolist()
EDc13 = (100-table['EDc13']).tolist()
EDc14 = (100-table['EDc14']).tolist()
EDc15 = (100-table['EDc15']).tolist()
EDc16 = (100-table['EDc16']).tolist()

table_r =pd.DataFrame({'Dates':Dates, 'EDc1': EDc1, 'EDc2': EDc2, 'EDc3': EDc3, 'EDc4': EDc4, 'EDc5': EDc5,
                 'EDc6': EDc6, 'EDc7': EDc7, 'EDc8': EDc8, 'EDc9': EDc9, 'EDc10': EDc10, 'EDc11': EDc11,
                 'EDc12': EDc12, 'EDc13': EDc13, 'EDc14': EDc14, 'EDc15': EDc15, 'EDc16': EDc16})
table_r = table_r[['Dates','EDc1', 'EDc2', 'EDc3', 'EDc4', 'EDc5', 'EDc6','EDc7', 'EDc8', 'EDc9','EDc10','EDc11','EDc12','EDc13','EDc14', 'EDc15','EDc16']]
table_r.fillna(method='ffill', inplace= True)

# %%
# replacing outliers with mean rates
rates = ['EDc1', 'EDc2', 'EDc3', 'EDc4', 'EDc5', 'EDc6','EDc7', 'EDc8', 'EDc9','EDc10','EDc11','EDc12','EDc13','EDc14', 'EDc15','EDc16']

for x in rates:
    mean = sum(table_r[x])/ len(table_r[x])
    
    Q1 = table_r[x].quantile(0.25)
    Q3 = table_r[x].quantile(0.75)
    IQR = Q3 - Q1
    table_r[x] = table_r[x].mask((table_r[x]< (Q1 - 1.5* IQR)) | (table_r[x] > (Q3  + 1.5 * IQR)),mean) 
    table_r[x].fillna(method='ffill', inplace= True)
    table_r[x].fillna(method='bfill', inplace= True)

# %%
# %matplotlib notebook

# %%
graph = table_r.plot(kind='line',figsize=(10,8))
graph.legend(bbox_to_anchor=(1.0,1.0))
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig1, (ax1,ax2) = plt.subplots(1,2, figsize=(11.5, 5))

ax1.plot(table_r['Dates'],(table_r['EDc1']))

ax2.boxplot(table_r['EDc1'])
# Out:
# <img src="data:image/png;base64,..." width="1150">
# {'boxes': [<matplotlib.lines.Line2D at 0x122eb6a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x122d6518>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1221c160>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x12223a20>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x122e5940>,
#   <matplotlib.lines.Line2D at 0x122def28>]}

# %%
table_r['EDc1_1D'] = (table_r['EDc1'] - table_r['EDc1'].shift(1))*100
table_r['EDc2_1D'] = (table_r['EDc2'] - table_r['EDc2'].shift(1))*100
table_r['EDc3_1D'] = (table_r['EDc3'] - table_r['EDc3'].shift(1))*100
table_r['EDc4_1D'] = (table_r['EDc4'] - table_r['EDc4'].shift(1))*100
table_r['EDc5_1D'] = (table_r['EDc5'] - table_r['EDc5'].shift(1))*100
table_r['EDc6_1D'] = (table_r['EDc6'] - table_r['EDc6'].shift(1))*100
table_r['EDc7_1D'] = (table_r['EDc7'] - table_r['EDc7'].shift(1))*100
table_r['EDc8_1D'] = (table_r['EDc8'] - table_r['EDc8'].shift(1))*100
table_r['EDc9_1D'] = (table_r['EDc9'] - table_r['EDc9'].shift(1))*100
table_r['EDc10_1D'] = (table_r['EDc10'] - table_r['EDc10'].shift(1))*100
table_r['EDc11_1D'] = (table_r['EDc11'] - table_r['EDc11'].shift(1))*100
table_r['EDc12_1D'] = (table_r['EDc12'] - table_r['EDc12'].shift(1))*100
table_r['EDc13_1D'] = (table_r['EDc13'] - table_r['EDc13'].shift(1))*100
table_r['EDc14_1D'] = (table_r['EDc14'] - table_r['EDc14'].shift(1))*100
table_r['EDc15_1D'] = (table_r['EDc15'] - table_r['EDc15'].shift(1))*100
table_r['EDc16_1D'] = (table_r['EDc16'] - table_r['EDc16'].shift(1))*100
table_1D = table_r.loc[:,['Dates', 'EDc1_1D', 'EDc2_1D', 'EDc3_1D', 'EDc4_1D', 'EDc5_1D', 'EDc6_1D',
                       'EDc7_1D', 'EDc8_1D', 'EDc9_1D','EDc10_1D','EDc11_1D','EDc12_1D','EDc13_1D',
                       'EDc14_1D', 'EDc15_1D','EDc16_1D']]
table_1D = table_1D[1:]

# %%
#fig2, ((ax3,ax4),(ax5, ax6)) = plt.subplots(2,2, figsize=(12, 12))

#ax3.hist(table_1D['EDc1_1D'], bins = 30, range=[-15,15], normed = True, edgecolor='grey')
#ax4.hist(table_1D['EDc5_1D'], bins = 30, range=[-15,15], normed = True, edgecolor='grey')
#ax5.hist(table_1D['EDc9_1D'], bins = 30, range=[-15,15], normed = True, edgecolor='grey')
#ax6.hist(table_1D['EDc13_1D'], bins = 30, range=[-15,15], normed = True, edgecolor='grey')


#ax4.title.set_text('1W after >10bp move')

#ax3.set_xticks(np.arange(-15,16,2))

#ax3.set_ylabel('change (bps)')

#ax3.set_yticks(np.arange(0,0.65,0.05))

#y_vals3 = ax3.get_yticks()
#ax3.set_yticklabels(['{:3.2f}%'.format(x*100) for x in y_vals3])

#fig2.suptitle('EDc1')

# %%
daily = ['EDc1_1D', 'EDc2_1D', 'EDc3_1D', 'EDc4_1D', 
         'EDc5_1D', 'EDc6_1D','EDc7_1D', 'EDc8_1D', 
         'EDc9_1D','EDc10_1D','EDc11_1D','EDc12_1D',
         'EDc13_1D','EDc14_1D', 'EDc15_1D','EDc16_1D']

all_fut1D = []
for x in daily:
    all_fut1D.extend(table_1D[x])

# %%
fig3, ax7 = plt.subplots(1,1, figsize=(7,6 ))

ax7.hist(all_fut1D, bins = 40, range=[-20,20], normed = True, edgecolor='grey')

ax7.title.set_text('Distribution of 1993 Daily Moves')

ax7.set_xlabel('bps')
ax7.set_xticks(np.arange(-20,21,2))

ax7.set_ylabel('Probability')
ax7.set_yticks(np.arange(0,0.25,0.02))

y_vals7 = ax7.get_yticks()
ax7.set_yticklabels(['{:3.2f}%'.format(x*100) for x in y_vals7])
# Out:
# <img src="data:image/png;base64,..." width="700">
# ...

# %%
def count(list1,l,r):
    return len(list(x for x in list1 if l < x <= r))

# %%
count(all_fut1D, 10, 1000)/ len(all_fut1D)
# Out:
# 0.050347222222222224

# %%
table_r['EDc1_1W'] = (table_r['EDc1'] - table_r['EDc1'].shift(5))*100
table_r['EDc2_1W'] = (table_r['EDc2'] - table_r['EDc2'].shift(5))*100
table_r['EDc3_1W'] = (table_r['EDc3'] - table_r['EDc3'].shift(5))*100
table_r['EDc4_1W'] = (table_r['EDc4'] - table_r['EDc4'].shift(5))*100
table_r['EDc5_1W'] = (table_r['EDc5'] - table_r['EDc5'].shift(5))*100
table_r['EDc6_1W'] = (table_r['EDc6'] - table_r['EDc6'].shift(5))*100
table_r['EDc7_1W'] = (table_r['EDc7'] - table_r['EDc7'].shift(5))*100
table_r['EDc8_1W'] = (table_r['EDc8'] - table_r['EDc8'].shift(5))*100
table_r['EDc9_1W'] = (table_r['EDc9'] - table_r['EDc9'].shift(5))*100
table_r['EDc10_1W'] = (table_r['EDc10'] - table_r['EDc10'].shift(5))*100
table_r['EDc11_1W'] = (table_r['EDc11'] - table_r['EDc11'].shift(5))*100
table_r['EDc12_1W'] = (table_r['EDc12'] - table_r['EDc12'].shift(5))*100
table_r['EDc13_1W'] = (table_r['EDc13'] - table_r['EDc13'].shift(5))*100
table_r['EDc14_1W'] = (table_r['EDc14'] - table_r['EDc14'].shift(5))*100
table_r['EDc15_1W'] = (table_r['EDc15'] - table_r['EDc15'].shift(5))*100
table_r['EDc16_1W'] = (table_r['EDc16'] - table_r['EDc16'].shift(5))*100
table_1W = table_r.loc[:,['Dates', 'EDc1_1W', 'EDc2_1W', 'EDc3_1W', 'EDc4_1W', 'EDc5_1W', 'EDc6_1W',
                       'EDc7_1W', 'EDc8_1W', 'EDc9_1W','EDc10_1W','EDc11_1W','EDc12_1W','EDc13_1W',
                       'EDc14_1W', 'EDc15_1W','EDc16_1W']]
table_1W = table_1W[5:]

# %%
weekly = ['EDc1_1W', 'EDc2_1W', 'EDc3_1W', 'EDc4_1W', 
         'EDc5_1W', 'EDc6_1W','EDc7_1W', 'EDc8_1W', 
         'EDc9_1W','EDc10_1W','EDc11_1W','EDc12_1W',
         'EDc13_1W','EDc14_1W', 'EDc15_1W','EDc16_1W']

all_fut1W = []
for x in weekly:
    all_fut1W.extend(table_1W[x])

# %%
fig4, ax8 = plt.subplots(1,1, figsize=(7, 6))

ax8.hist(all_fut1W, bins = 30, range=[-15,15], normed = True, edgecolor='grey', color = 'green')

ax8.title.set_text('Distribution of 1993 Weekly Moves')

ax8.set_xlabel('bps')
ax8.set_xticks(np.arange(-20,21,2))

ax8.set_ylabel('Probability')
ax8.set_yticks(np.arange(0,0.12,0.01))

y_vals8 = ax8.get_yticks()
ax8.set_yticklabels(['{:3.2f}%'.format(x*100) for x in y_vals8])
# Out:
# <img src="data:image/png;base64,..." width="700">
# ...

# %%
count(all_fut1W, -5, 5)/ len(all_fut1W)
# Out:
# 0.32610887096774194

# %%
#finding the spreads between c1 and c6
table_61 = table_r.loc[:,['Dates',"EDc1", "EDc6"]]
table_61["spread"] = table_61["EDc6"] - table_61["EDc1"]

# %%
fig4, (ax9,ax10) = plt.subplots(2,1, figsize=(11.5, 8))
ax9.plot(table_61['Dates'],table_61['spread'])
ax10.boxplot(table_61['spread'], vert = False)
# Out:
# <img src="data:image/png;base64,..." width="1150">
# {'boxes': [<matplotlib.lines.Line2D at 0x12f9e128>],
#  'caps': [<matplotlib.lines.Line2D at 0x12fa7b00>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x12faed30>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x12fae518>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x12f9ea90>,
#   <matplotlib.lines.Line2D at 0x12f9ec88>]}
